# %% [markdown]
# # NLP Project

# %%
import nltk
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.model_selection import train_test_split
from matplotlib import cm
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from sklearn.linear_model import SGDClassifier
from gensim.models import Word2Vec
import string, re
string.punctuation

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# !pip install gensim

# %%
df = pd.read_csv('https://query.data.world/s/koumlilh5zav774mivuajaeahtefko',encoding= 'unicode_escape')
df = df[df.is_there_an_emotion_directed_at_a_brand_or_product != "I can't tell"]

# %%
df
# Out:
#                                              tweet_text  \
# 0     .@wesley83 I have a 3G iPhone. After 3 hrs twe...
# 1     @jessedee Know about @fludapp ? Awesome iPad/i...
# 2     @swonderlin Can not wait for #iPad 2 also. The...
# 3     @sxsw I hope this year's festival isn't as cra...
# 4     @sxtxstate great stuff on Fri #SXSW: Marissa M...
# ...                                                 ...
# 9088                      Ipad everywhere. #SXSW {link}
# 9089  Wave, buzz... RT @mention We interrupt your re...
# 9090  Google's Zeiger, a physician never reported po...
# 9091  Some Verizon iPhone customers complained their...
# 9092  Ï¡Ïàü_ÊÎÒ£Áââ_£â_ÛâRT @...
#
#      emotion_in_tweet_is_directed_at  \
# 0                             iPhone
# 1                 iPad or iPhone App
# 2                               iPad
# 3                 iPad or iPhone App
# 4                             Google
# ...                              ...
# 9088                            iPad
# 9089                             NaN
# 9090                             NaN
# 9091                             NaN
# 9092                             NaN
#
#      is_there_an_emotion_directed_at_a_brand_or_product
# 0                                      Negative emotion
# 1                                      Positive emotion
# 2                                      Positive emotion
# 3                                      Negative emotion
# 4                                      Positive emotion
# ...                                                 ...
# 9088                                   Positive emotion
# 9089                 No emotion toward brand or product
# 9090                 No emotion toward brand or product
# 9091                 No emotion toward brand or product
# 9092                 No emotion toward brand or product
#
# [8937 rows x 3 columns]

# %% [markdown]
# # Data Cleaning

# %%
text_cleaning_re = "@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+"

stop_words = stopwords.words('english')
stop_words += list(string.punctuation)
stop_words += ["''", '""', '...', '``', '’', '“', '’', '”', '‘', '‘', '©']
sw_set = set(stop_words)

# %%
def process_article(article):
    article = re.sub(text_cleaning_re, ' ', str(article).lower()).strip()
    tokens = nltk.word_tokenize(article)
    stopwords_removed = [token.lower() for token in tokens if token.lower() not in sw_set]
    return stopwords_removed

# %%
data = df['tweet_text']
target = df['is_there_an_emotion_directed_at_a_brand_or_product']

# %%
processed_data = list(map(process_article, data))

# %%
lemmatizer = WordNetLemmatizer() 
lemmatized_output = []

for listy in processed_data:
    lemmed = ' '.join([lemmatizer.lemmatize(w) for w in listy])
    lemmatized_output.append(lemmed)

# %% [markdown]
# ## EDA

# %%
df.isna().sum()
# Out:
# tweet_text                                               1
# emotion_in_tweet_is_directed_at                       5655
# is_there_an_emotion_directed_at_a_brand_or_product       0
# dtype: int64

# %%
plt.figure(figsize=(10,4))
df['is_there_an_emotion_directed_at_a_brand_or_product'].value_counts().plot(kind='bar');

# %%
plt.figure(figsize=(10,4))
df['emotion_in_tweet_is_directed_at'].value_counts().plot(kind='bar');

# %%
# wordcloud = WordCloud(colormap='Spectral').generate_from_frequencies()
# plt.figure(figsize=(10,10), facecolor='k')
# plt.imshow(wordcloud, interpolation='bilinear')
# plt.axis("off")
# plt.tight_layout(pad=0)
# plt.show()

# %% [markdown]
# #### Most Frequent Words by Category?

# %% [markdown]
# #### Word Count by Category? Do people that like brand talk longer about it?

# %% [markdown]
# ## Train Test Split

# %%
X_lem = lemmatized_output
y_lem = target

# %%
X_train_lem, X_test_lem, y_train_lem, y_test_lem = train_test_split(X_lem, y_lem, test_size=0.40, random_state=1)

# %%
sentiments = ['Negative emotion','Positive Emotion','No emotion toward brand or product']

# %%
nb_pipeline = Pipeline([('vect', CountVectorizer()),
               ('tfidf', TfidfTransformer()),
               ('clf', MultinomialNB())])
nb_pipeline.fit(X_train_lem, y_train_lem)


from sklearn.metrics import classification_report
y_pred = nb_pipeline.predict(X_test_lem)

print('accuracy %s' % accuracy_score(y_pred, y_test_lem))
print(classification_report(y_test_lem, y_pred,target_names=sentiments))
# Out:
# accuracy 0.6483916083916084
#                                     precision    recall  f1-score   support
#
#                   Negative emotion       1.00      0.01      0.02       228
#                   Positive Emotion       0.64      0.95      0.77      2164
# No emotion toward brand or product       0.68      0.21      0.32      1183
#
#                           accuracy                           0.65      3575
#                          macro avg       0.78      0.39      0.37      3575
#                       weighted avg       0.68      0.65      0.57      3575

# %%
#Generate confusion matrix
labels = np.unique(y_test_lem)
cm = confusion_matrix(y_test_lem, y_pred,labels=labels) 

cm_df = pd.DataFrame(cm,index=labels, columns=labels)

#Plot
plt.figure(figsize=(12, 8))

sns.heatmap(cm_df,
            cmap='coolwarm', 
            annot=True, 
            fmt='g')

plt.ylabel('Actual label', fontsize = 13)
plt.xlabel('Predicted label', fontsize = 13)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train_lem, y_train_lem)

y_pred = logreg.predict(X_test_lem)

print('accuracy %s' % accuracy_score(y_pred, y_test_lem))
print(classification_report(y_test_lem, y_pred,target_names=sentiments))
# Out:
# accuracy 0.6377622377622377
#                                     precision    recall  f1-score   support
#
#                   Negative emotion       0.46      0.35      0.40       228
#                   Positive Emotion       0.71      0.73      0.72      2164
# No emotion toward brand or product       0.53      0.52      0.52      1183
#
#                           accuracy                           0.64      3575
#                          macro avg       0.57      0.53      0.55      3575
#                       weighted avg       0.63      0.64      0.63      3575
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
sv = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=1, max_iter=5, tol=None)),])
sv.fit(X_train_lem, y_train_lem)
y_pred = sv.predict(X_test_lem)

print('accuracy %s' % accuracy_score(y_pred, y_test_lem))
print(classification_report(y_test_lem, y_pred,target_names=sentiments))
# Out:
# accuracy 0.64
#                                     precision    recall  f1-score   support
#
#                   Negative emotion       1.00      0.01      0.03       228
#                   Positive Emotion       0.63      0.98      0.77      2164
# No emotion toward brand or product       0.76      0.14      0.23      1183
#
#                           accuracy                           0.64      3575
#                          macro avg       0.80      0.38      0.34      3575
#                       weighted avg       0.70      0.64      0.54      3575

# %%
#Generate confusion matrix
labels = np.unique(y_test_lem)
cm = confusion_matrix(y_test_lem, y_pred,labels=labels) 

cm_df = pd.DataFrame(cm,index=labels, columns=labels)

#Plot
plt.figure(figsize=(12, 8))

sns.heatmap(cm_df,
            cmap='coolwarm', 
            annot=True, 
            fmt='g')

plt.ylabel('Actual label', fontsize = 13)
plt.xlabel('Predicted label', fontsize = 13)
plt.show()

# %%
# positive_list = []
# negative_list = []
# for i in range(len(lemmatized_output)):
#     if lemmatized_output[i][1] == "Positive emotion":
#         positive_list.extend(lemmatized_output[i][0])
#     else:
#         negative_list.extend(lemmatized_output[i][0])

# %%
# tweet_types = ('Negative emotion','Positive Emotion','No emotion toward brand or product')
# encoding = OneHotEncoder(handle_unknown='ignore')
# encoding_df = pd.DataFrame(enc.fit_transform(df[['is_there_an_emotion_directed_at_a_brand_or_product']]).toarray())

# %%
# df = df.join(encoding_df)
# df

# %%
# df.rename(columns={0:'Unknown',1:'Negative',2:'No Emotion',3:'Positive'}, inplace=True)

# %%
lemmatized_output
# Out:
# ['wesley83 3g iphone 3 hr tweeting rise austin dead need upgrade plugin station sxsw',
#  'know fludapp awesome ipad iphone app likely appreciate design also giving free t sxsw',
#  'wait ipad 2 also sale sxsw',
#  'hope year festival crashy year iphone app sxsw',
#  'great stuff fri sxsw marissa mayer google tim reilly tech book conference amp matt mullenweg wordpress',
#  'new ipad apps speechtherapy communication showcased sxsw conference iear edchat asd',
#  'nan',
#  'sxsw starting ctia around corner googleio hop skip jump good time android fan',
#  'beautifully smart simple idea rt madebymany thenextweb wrote hollergram ipad app sxsw',
#  'counting day sxsw plus strong canadian dollar mean stock apple gear',
#  'excited meet samsungmobileus sxsw show sprint galaxy still running android 2 1 fail',
#  'find amp start impromptu party sxsw hurricaneparty wait til android app come',
#  'foursquare ups game time sxsw still prefer gowalla far best looking android app date',
#  'got ta love sxsw google calendar featuring top party show case check rt hamsandwich via ischafer gt',
#  'great sxsw ipad app madebymany',
#  'haha awesomely rad ipad app madebymany hollergram sxsw',
#  'holler gram ipad itunes app store via marc ken sxsw',
#  'noticed dst coming weekend many iphone user hour late sxsw come sunday morning sxsw iphone',
#  'added sxsw flight planely matching people plane airport also downloaded klm iphone app nicely done',
#  'must sxsw app rt malbonster lovely review forbes sxsw ipad app holler gram',
#  'need buy ipad2 austin sxsw sure need q austin apple store',
#  'oh god sxsw app ipad pure unadulterated awesome easier browse event ipad website',
#  'okay really yay new foursquare android app 11 kthxbai sxsw',
#  'photo installed sxsw iphone app really nice',
#  'really enjoying change gowalla 3 0 android looking forward seeing else amp foursquare sleeve sxsw',
#  'rt laurieshook looking forward smcdallas pre sxsw party wed hoping win ipad resulting shameless promotion chevysmc',
#  'rt haha awesomely rad ipad app madebymany hollergram sxsw via michaelpiliero',
#  'someone started austin partnerhub group google group pre sxsw great idea',
#  'new 4sq3 look like going rock update iphone android push tonight sxsw keepaustinweird',
#  'right gowalla 3 app android sweeeeet nice job team sxsw',
#  'smart madebymany hollergram ipad app sxsw may leave vuvuzela home',
#  'must app ipad going sxsw hollergram',
#  'attn sxsw frineds mention register gdgtlive see cobra iradar android link',
#  'anyone sxsw want sell old ipad',
#  'anyone sxsw bought new ipad want sell older ipad',
#  'sxsw oooh rt mention google launch major new social network called circle possibly today link',
#  'best rt mention ha first line ipad2 sxsw quot pop quot apple store event planner eventprofs pcma engage365',
#  'spin play new concept music discovery ipad mention amp spin com link itunes sxsw mention',
#  'false alarm google circle coming probably ever link google circle social sxsw',
#  'vatornews google apple force print medium evolve link sxsw',
#  'great weather greet sxsw still need sweater night apple putting quot flash store quot downtown sell ipad2',
#  'hootsuite hootsuite mobile sxsw update iphone blackberry amp android whether getting friend link',
#  'hey sxsw long think take u make iphone case answer mention using zazzlesxsw make one',
#  'mashable ipad 2 take sxsw video ipad sxsw gadget link',
#  'pad rt mention new ubersocial iphone app store includes uberguide sxsw sponsored link',
#  'ipad2 smartcover open instant access waited get one link apple sxsw',
#  'hand held hobo drafthouse launch hobo shotgun iphone app sxsw link',
#  'hooray rt mention apple opening pop store austin sxsw mention link',
#  'orly mention google set launch new social network circle today sxsw',
#  'wooooo mention apple store downtown austin open til midnight sxsw',
#  'khoi vinh mention say conde nast headlong rush ipad publishing quot fundamental misunderstanding quot platform sxsw',
#  'mention link lt help forward doc anonymous account techie amp ppl help u jam libya sxsw',
#  'link edchat musedchat sxsw sxswi classical newtwitter',
#  'mention mention location based fast fun future link via mention sxsw',
#  'mention mention google connect digital amp physical world mobile link sxsw mention',
#  'mention mention talking link google effort allow user open system bettercloud sxsw',
#  'link rt mention quot google tweet quot new quot think speak quot mark belinsky 911tweets panel sxsw',
#  'link rt mention 1st stop sxsw chaos amp mention hunt austin java get spy game 4 chance 2 win ipad',
#  'link rt mention sxsw check holler gram ipad app mention link',
#  'mention amp mention fun google pic sxsw link',
#  'quot via mention link guy kawasaki talk enchanted sxsw know stuff book internet apple sxsw quot',
#  'futuremf mention link spec recipe web google search link sxsw',
#  'omfg rt mention heard apple pop store downtown austin pic already gowalla link sxsw ipad2',
#  'smile rt mention think apple quot pop store quot austin would lot interesting actually know popped sxsw',
#  'rt mention line apple store insane sxsw',
#  'agree rt mention wait fiona apple town somebody kidnap put recording studio record new album sxsw',
#  'sxsw mention mention wan na buy drink 7pm fado 4th link join u',
#  'attending mention ipad design headache sxsw link',
#  'boooo rt mention flipboard developing iphone version android say mention sxsw',
#  'check mention mention amp mention line ipad 2 austin power sxswi sxsw link',
#  'check rt mention giving added value location based service need battle check fatigue google pnid sxsw',
#  'chilcott mention sxsw stand talking blogger staff late win competition best tweet mentioning mention shirt',
#  'rt mention come party w google tonight sxsw link band food art ice cream nifty interactive map',
#  'gowalla mention promise launch foursquare check groupon reward type service sxsw finger crossed link',
#  'ha ha rt mention sxsw news yahoo com loosing search traffic new site google com doubt last tho w weird name',
#  'holla rt mention google party best ever get butt sxsw',
#  'love mention iphone case sxsw get phone fail',
#  'worship mention link sxsw',
#  'ipad2 rt mention droid amp mac rt mention agnerd confession using laptop ipad amp blackberry follow sxsw',
#  'launching mention sxsw rt mention mention denies social network called circle debut today despite report link',
#  'new post mention iphone app make easy connect social network people meet link sxsw',
#  'nice mention iphone app behaving today crash yesterday ridiculous sxsw',
#  'nice rt mention apple opening popup store ipad launch downtown austin sxsw link via mention',
#  'nice rt mention hey apple fan get peek space slated pop sxsw apple store tomorrow link',
#  'one thing mention great get great earth face google company love sxsw sxwsi',
#  'stay tune mention showcase h4ckers link sxsw',
#  'thank mention mention touchingstories preso sxsw deck link',
#  'thank mention awesome sxsw party link',
#  'thanks rt mention trying contact friend family japan mention created person finder link sxsw',
#  'thanks mention mention new speech ipad apps showcased sxsw conf link sxswh sxsh',
#  'thanks mention publishing news new medical apps sxswi conf blog link sxsw sxswh mhealth',
#  'mention sxsw provide iphone charger changed mind going next year',
#  'wonder mention amp mention apple flashmob tcrn ch fcs45j sxsw ipad2',
#  'wonder mention putting tip mention api sxsw suxsw',
#  'xmas rt mention shiny new mention mention mention apps new garyvee book pop ipad 2 store sxsw christmas nerd',
#  'yai rt mention new ubersocial iphone app store includes uberguide sxsw sponsored cont link',
#  'yes rt mention hey mention got another gem gt free mention sxsw link sxsw',
#  'fast fun amp future mention google presenting sxsw search local mobile',
#  'gsd amp amp google industry party tonight mention see u link sxsw austin welivehere gsdm',
#  'new buzz quot mention google launch major new social network called circle possibly today link rt mention sxsw quot',
#  'headline quot ipad 2 must gadget sxsw quot hmm could seen one coming link gadget',
#  'know quot dataviz quot translates quot satanic quot iphone sayin sxsw',
#  'mention quot google launched checkins month ago quot check in ok check out future sxsw bizzy',
#  'mention quot google launched checkins month ago quot check in ok check out future sxsw bizzy via mention',
#  'mention quot google tweet quot new quot think speak quot mark belinsky 911tweets panel sxsw',
#  'attending quot left brain search google right brain search x quot bettersearch talking future search engine sxsw',
#  'hp open quot mobile park quot amp content incubator sxsw link apple construct quot pop quot store link',
#  'kawasaki quot c lewis level reasoning apple continued existence evidence existence god quot bawling sxsw',
#  'kawasaki quot pagemaker saved apple quot oh day sxsw jwtatl enchantment',
#  'kawasaki quot pagemaker saved apple quot oh day sxsw jwtatl enchantment via mention',
#  'spark android teamandroid award sxsw read link',
#  'unboxing apple sxsw mention apple store sxsw link',
#  'sxsw apple ipad 2 great thought w japan apac region dealing w earthquake amp tsunami trauma sxswi',
#  'sxsw apple school marketing expert sxsw cnet blog link',
#  'sxsw apple school marketing expert link',
#  'sxsw apple school marketing expert link',
#  'temporary apple store def tent powerhouse gym sxsw link',
#  'temporary apple store 6th congress sxsw along 10 000 happy hipster',
#  'mention apple win sxsw link opening temporary store downtown austin support ipad2 launch good',
#  'ipad austin trending today fun sxsw nerdy nerd',
#  'headed austin sxsw check map newbie link mention mention mention mention enjoy',
#  'funny austin trending sxsw matter minute point least according twitter iphone',
#  'christian ipad iphone devs want talk u sxsw maybe wk together cool app mention',
#  'sxsw ux ipad uxdes remember ultimately aware audience app targeted towards unexpected experience good',
#  'apple ipad2 taken sxsw austin storm link mention excited part mobile',
#  'haz ipad2 ifrom sxsw gr8 link',
#  'stack ipad2 waiting bought sxsw got mine hassle apple handled perfectly link',
#  'google mobile future elusive power link via mention eurorscg sxsw sxswi',
#  'notatsxsw sxsw link free download meet nearby pep',
#  'smallbiz need review play google place got app link seo sxsw',
#  'smallbiz need review play google place got app link seo sxsw',
#  'samsung sony follow apple hp lead mention link austin atx sxsw',
#  'samsung sony follow apple hp lead mention link austin atx sxsw via mention rg',
#  'take sxsw rt mention major south korean director get 130 000 make movie entirely iphone link',
#  'beautiful sxsw mention apple store sxsw pic link',
#  'q1 sxsw sxswi prep amazing pre push locally focus location based google owns 10 region billboard pr20chat',
#  'sxsw account need follow apps download iphone',
#  'headed sxsw want share gather contact info link turn iphone business card broadcaster',
#  'headed sxsw want share gather contact info link turn iphone link',
#  'btw sxsw apple store sold 3g model vzw amp amp',
#  'must sxsw app rt mention lovely review forbes sxsw ipad app holler gram link',
#  'temporary sxsw apple store apple sneaky usual link',
#  'anyone sxsw pop apple store austin got ta hopping place today',
#  'mention sxsw beta testing interactive book ipad app moonbot studio louisiana cool app',
#  'apple sxsw day one seeing ton ipad2',
#  'fastball sxsw giving away two new ipad2 wifi 32g black apple cover tweet mention fo info sxswi attsxsw tonight mention bo lt house',
#  'anyone sxsw chance check pop apple store wondering worth trek convention center',
#  'mention sxsw ipad store sold everything except 64gig wifi white mention manage get',
#  'mention sxsw ipad store sold everything except 64gig wifi white also known white jean configuration',
#  'offered sxsw ipad promo ninjafinder user fan sxsw suck sxsw',
#  'sxsw austin conference google search interactive music film',
#  'anyone sxsw know apple selling ipad 2',
#  'anyone sxsw know apple store new shipment ipads yet',
#  'marc ecko sxsw launch iphone app autodial political change link edreform edtech eduvc fightthepaddle',
#  'poursite sxsw learning life changing impact ipad real people actual life bravo',
#  'sxsw lonelyplanet austin guide iphone free limited time link lp travel',
#  'free sxsw mp3 downloads time itunes link',
#  'anyone sxsw heading aclu event seen owt google circle',
#  'sxsw prompt memory go google map describe childhood walk',
#  'apple sxsw store still ipad 2 short line',
#  'essential sxsw tool link',
#  'left sxsw tradeshow demo mention google theatre ok get see presenter using',
#  'following sxsw tweet google realtime four platform tweet deck listening panel realizing spoken one today',
#  'anyone sxsw want ipad 2 line pick one someone willing pay 50 grab 1',
#  'anyone sxsw want make quick hundred dollar new ipad2 ad hoc apple store get hundred plus cost',
#  'solving sxsw induced iphone toilet crisis apple store mention crisis',
#  'monday sxsw barry diller new york time congress lunch w hotel party google party six dirty martini monday',
#  'attending sxsw austin guide mention free download itunes link lp',
#  'seriously sxsw testing mobile apps constant ipad crash causing lost schedule sync wp7',
#  'ready sxsw iphone apps 2 make ur blogging easier link sxsw sxswi',
#  'ipad2 sxsw conflagration doofusness link',
#  'attention sxsw er link rumored pop temporary apple store sxsw ipad 2 launch need',
#  'went sxswi lousy ipad sxsw link',
#  'hey sxsw sxswi folk want learn security come bsidesaustin link',
#  'attending sxswi work iphone ipad game development looking hire austin based io developer man let talk sxsw',
#  'winning picture android google sxsw link',
#  'gsd amp google 7 10 rt mention best party hit tonight sxsw mention mention',
#  'gsd amp google industry party sxsw mention great meet link',
#  'spent 1 000 come sxsw already used ipad 1 wait couple city block ipad2 sxsw link',
#  'sxsw day 1 marissa mayer google connect digital amp physical world mobile link',
#  'behind 100 email give 1 line iphone composed reply sxsw protip',
#  'like 10pm night line around block popup apple store selling ipad2s sxsw',
#  'mention 1154 free song sxsw year alone link',
#  '150 million mobile user google map mobile sxsw',
#  'currently 150 people line quot pop apple store quot sxsw',
#  'ipad 2 available sxsw 64gb wifi model 699 plus optional leather smart cover 69',
#  'love 2 entertain please grateful link edchat musedchat sxsw sxswi classical newtwitter',
#  'le 2 hour announce detail ipad 2 giveaway sxsw sxswi',
#  '2 ipad 2 seen wild people say fast still pic terrible sxsw',
#  'ipad 2 queue sxsw course',
#  'ipad 2 take sxsw video mention link',
#  'many ipad 2 snapping away keynote slide sxsw',
#  'apple 200m user credit card sync itunes one click purchase winning sxsw',
#  '2nd cocktail quot texas snowflake quot mention google cnngrill sxsw',
#  'new post 3 iphone apps using south southwest interactive link sxsw sxswi',
#  'new post 3 iphone apps using south southwest interactive sxsw sxswi link',
#  'sweet new 3 google map demo going ballroom sxsw',
#  '35 million mile per day driving google map navigation sxsw',
#  'rt 4 p ipad2 line apple store longer wider 250 people one hour sxsw',
#  'u smart 4 packing extra rt mention way sunny austin sxsw extra iphone stow case mention mention',
#  'wonder 4sqwill attempt block gowalla cross checkins way facebook blocked google contact connection sxsw lbswars',
#  'sxsw day 5 apple store still line growing link',
#  'check 5 step bulletproof ux strategy sxsw link sxsw rhjr ux5 link',
#  'wandering 6th street girl stopped ceviche mojitos apple juice amp ice cream sxsw',
#  'band sxsw want share track audience stage use frostwire android wi fi available',
#  'got busy week ahead new book google apps available amazon amp attending sxsw',
#  'believe went aussie sxsw rt mention ipad 2 sold 70 went new buyer report link',
#  'mention google spreadsheet 270 party sxsw year link mention plan going sxsw party',
#  'guy line apple pop store sixth street austin quot guy quot told sxsw',
#  'u iphone need car use zimride etc share ride sxsw shareable',
#  'seen lot tablet every single one ipad sxsw',
#  'receiving lot mention message telling sexy response post looking meet fellow christian iphone devs sxsw',
#  'picked mophie battery case 4 iphone prep sxsw lugging around laptop amp using phone huge win last year',
#  'thats news p rt google launch major new social network called circle possibly today link sxsw',
#  'took piss trade show ipad one hand iphone pissing kiiiiiilling right sxsw',
#  'rumor monger good read google circle preview mention sxsw link mention via mention socbiz fb',
#  'hobo shotgun iphone game link sxsw',
#  'hobo shotgun video game coming ipad iphone user yes please link sxsw',
#  'build store le 24 hour one biggest launch company history got apple sxsw ipad2',
#  'took survey iphone starbucks line got free starbucks gift card instant research instant gratification sxsw gsdm',
#  'apple temporary retail store austin ipad 2 release today open 5pm sxsw sxswi ipad2',
#  'read groupme sxsw sound like incredible app available android phone yet',
#  'wondering circle gt google reveal new social network sxsw link',
#  'google search local marissa mayer sxsw',
#  'wondering street closure sxsw made google map show link sxsw austin',
#  'google another go social quot google circle quot sxsw google',
#  'question inside ipad 2 fire way sxsw',
#  'paraormal activity sanctuary iphone game sketching ar experience interactivity quot magic lense quot eduar sxsw',
#  'apple iie ad 85 si swimsuit issue garage sale sxsw link',
#  'flipboard add instagram photo social search apps link apple socialsearch sxsw',
#  'spent aftrnoon frozen lake photographing brother scott amp mention team catch sxsw th weeknd link',
#  'iphone alarm botch timechange many sxsw er freak late flight missed panel behind bloody mary',
#  'shout lady holding ipad 2 free sxsw show take photo sipping free beer cc mention',
#  'dj hoodie allen due respect probably make way back google sxsw',
#  'meant also wish sxsw dyac stupid iphone',
#  'audioboo american dream bust link ipad sxsw bum begger u socialart documentally',
#  'skifta app based medium shifting service turn android phone sxsw mashable sxswi link',
#  'rumor apple store opening sxsw 6th amp congress sign point yes link',
#  'apple security guy lock store sxsw link',
#  'apple security guy lock store sxsw realtime sxsw link curated mention',
#  'got ipad 2 sxsw link cc mention',
#  'picked ipad 2 sxsw pop apple store 15 minute wait',
#  'brilliant enlightening game mechanic presentation mention google sxsw',
#  'gsd amp google sitting tree link sxsw gsdm',
#  'pic winning ipad unsix sxsw cc mention mention link cont link',
#  'iphone thirsty sxsw mention chevy volt lounge w 16 others link',
#  'iphone thirsty sxsw mention chevy volt lounge w 16 others link link',
#  'came left sxsw iphone playing song chosen random skream listening record wall appropriate',
#  'marketing sale genius link apple sxsw',
#  'arduino android flaming skull link refrigerator speaks salon k 3 30pm mention mention sxsw smartthings',
#  'reminder android chrome tt talk mention 1 pm today link sxsw',
#  'ipad 2 v android v world panel sxsw today 3 30pm mention link',
#  'backupify announces cloudsight search first searchable archive solution social medium google apps sxsw sxswi link',
#  'google announcing social network quot circle quot via sxsw tweet interesting myopia cause buzz joke interesting',
#  'need sxsw ipad iphone laptop dictaphone vid camera wow love meet real cerebellum charged people',
#  'u see anything google circle sxsw mention mention',
#  'sxsw app iphone ridiculous personal planner next 5 day',
#  'sxsw app android huge prop mention mention mention amp mention get link',
#  'found app kyping iphone geolocation amp releasing background need patch mention batterykiller sxsw',
#  'sxsw app iphone live rsvp event phone amp check sundayswagger eventbrite com 3 20 scoremore',
#  'iphone app screen sxsw missing link',
#  'love app awesome rt mention must see android app sxsw quot bizzy quot link',
#  'sxsw apple quot pop quot store nut still packed 11 30 link',
#  'say apple sxsw popup store austin link mention mention',
#  'breaking apple announces partnership w porn industry new ipad2 video chat app called quot facetime quot sxsw',
#  'course apple built temp store austin texas understand concept corralling cattle sxsw pickmeupanipad2',
#  'love apple let something like retail store near sxsw keep away opening pop store link',
#  'surprise apple opened pop store austin nerd town sxsw get new link cnet',
#  'surprise apple opened pop store austin nerd town sxsw get new ipads link cnet',
#  'surprise apple opened pop store austin nerd town sxsw get new ipads link',
#  'surprise apple opened pop store austin nerd town sxsw get new ipads link',
#  'technews apple head sxsw set temporary store austin link tech news apple ipad 2 rance wilemon sxsw tech',
#  'mention apple great example retail store layed future register checkout line sxsw',
#  'mention apple opening temporary store downtown austin sxsw ipad 2 launch link gswsxsw',
#  'mention apple opening temporary store downtown austin sxsw ipad 2 launch quot oh yay traffic',
#  'technews apple opening pop store austin sxsw link tech news american statesman apple apple apple sxsw tech',
#  'technews apple opening pop store austin sxsw geekfest apple link tech news apple brian lam ipad 2 sxsw tech',
#  'sxsw apple popup store open noon fresh shipment ipad 2 pretty sure going get one finger crossed',
#  'technews apple save sxsw set open pop store link tech news apple sxsw tech',
#  'sxsw apple school marketing expert link',
#  'sxsw apple school marketing expert link',
#  'sxsw apple school marketing expert link via mention',
#  'sxsw apple school marketing expert link via mention lt lt true love loathe one marketing like',
#  'sxsw apple school marketing expert cnet link',
#  'sxsw apple school marketing expert cnet blog link austin atx retail',
#  'mention apple store downtown austin open til midnight sxsw mention still time',
#  'mention apple store downtown austin open til midnight sxsw ipad2 left stock',
#  'apple store congress link sxsw austin',
#  'quot apple store mall sunday 10x crowded line fake need fucking dongle quot genius let sxsw',
#  '2wks apple store 6th austin street opened sxsw',
#  'special apple store opening 6th congress sxsw amp ipad 2 launch www apple com retail thedomain apple ipad2 sxsw fb',
#  'makeshift apple store 6th congress kidding amazing sxsw apple',
#  'temporary apple store sxsw huge line link',
#  'temporary apple store sxsw really cool ipad 2 apple sxsw fanboy',
#  'temporary apple store set sxsw shit temptation going control',
#  'temporary apple store sxsw line go around block link',
#  'temporary apple store open mention 6th amp congress tomorrow ipad2 sxsw',
#  'temporary apple store open 5pm 6th congress line already growing ipad view io link via mention sxsw',
#  'temporary apple store block office wait see line tomorrow photo come sxsw ipad2',
#  'sxsw apple store open noon day close run ipad2s buy stock 10 year ago',
#  'base camp apple sxsw link',
#  'ipad news apps last year sxsw link',
#  '10 iphone apps probably need use sxsw link',
#  '150 million mobile google map user mention sxsw',
#  'line already forming apple pop store austin people see festival link sxsw',
#  'android rt mention 10 new mobile apps using sxsw link',
#  'sxsw attending sxsw report see android phone get bannka app',
#  'ipad apps like software development release start working update sxsw',
#  'tweet stalled data sluggish come amp verizon embarrassing iphone customer switched sxsw iphone',
#  'tweeting google coming circle platform today outside circle keep itsnot sxsw',
#  'mention stupid find sxsw mac link special price game mac',
#  'slate see much traffic mobile safari app ipad sxsw electricnews',
#  'unloading apple store corner 6th congress austin temp store sxsw link',
#  'great day sxsw jaloux mention amp new ipad look school bus 1st day school link',
#  'arrived sxsw mention issue resolved dying use iphone app cant login rt mention',
#  'sxsw screenburn mention launch client new iphone game travellerarlaunch find link',
#  'anyone sxsw want see demo piccraft ipad 2 find',
#  'sxsw could spend mention teaching theater alone look schedule link',
#  'sxsw meet u fado give wristband magically lead beer come say hi link',
#  'sxsw want ipad 2 apple setting temporary store check link',
#  'overheard sxsw quot ipad relaxing computer quot agreed ipad apple',
#  'overheard sxsw interactive quot arg hate iphone want blackberry back quot shocked',
#  'sxsw meet author host android devs sat 12 30pm hilton room 615ab',
#  'mention sxsw quot apple come cool technology one ever heard go conference quot',
#  'sxsw apple set 5 000 square foot temporary store sxsw sell new ipads test potential traffic link',
#  'overheard sxsw quot google launch product people event quot',
#  'nerd bait sxsw apple set open popup shop core sxsw action link',
#  'long line sxsw else apple store link',
#  'last year sxswi everbody talking ipad year social medium driven revolution year better sxsw',
#  'long line apple pop store ipad 2 great marketing apple sxsw',
#  'mention google 4 people work 7 people rather 7 people work 4 agileagency sxsw',
#  'knackered home playing ipad updating iphone timeline smashed partytweets make go bed sxsw',
#  'overheard mdw second quot halfway iphone battery already even boarded plane sxsw quot amateurhour',
#  'technews sxsw apple school marketing expert link tech news apple job co sxsw tech',
#  'first day sxsw fun final presentation google doodle googledoodle sxsw',
#  'huge line apple store austin sxsw crowd tripping get new ipad',
#  'ur google aclu 80 party u sxsw',
#  'queue apple pop store sxsw link',
#  'posted dmi house intimate stranger stage got restaurant crowd sitting deal wif sxsw link',
#  'woman google talk sounded like chelsea handler lol sxsw',
#  'laughed ipad spent week hauling macbook everywhere really want ipad shoulder rub sxsw',
#  'sxsw attendee need qr code reader iphone tweet u image badge first 5 get optiscan free',
#  'hey sxsw attendee hop line apple store four day til new ipad2 come',
#  'anyone attending google amp aclu party mention sxsw could plz picture thanks sxsw',
#  'march 11 austin tx people line sxsw registration apple store',
#  'landed austin spotted google place ad sxsw airport quot ultimate austin pocket guide quot like yelp itouru',
#  'took away lego pit replaced recharging station sxsw might check price iphone crap samsung android',
#  'mention awesome meet mention mention mention standing apple queue sxsw yesterday day 2 lt lt cute',
#  'mention bad apple show late q process poo poos idea leaf early even quot creative quot busy gamestorming sxsw',
#  'mention bahrain govt turned google earth result people learned govt turn back sxsw',
#  'trying balance power power need iphone v ipad sxsw 3g ipad suck quick might go airplane mode',
#  'racing ballroom see mention marissa mayer sxsw sxswi',
#  'iphone battery 100 winning sxsw',
#  'iphone battery keep tweet thanks apple sxsw precommerce',
#  'another google wave rt mention interrupt regularly scheduled sxsw geek programming w big google news link',
#  'fun watch ipadmadness rt mention apple opening pop store austin sxsw link sxsw',
#  'control apple set open popup shop core sxsw action link via mention cc mention',
#  'yeah sure gt rt mention mention mention check link sxsw google',
#  'celebrate beauty web mention msft ie9 launch amp play new html5 game win ipad2 link sxsw',
#  'texas amazing met many influential people work twitter foursquare microsoft even apple sxsw winning',
#  'woke iphone finished recharging mean got enough sleep last night right sxsw',
#  'quiet storm sxsw looking forward seeing google marissa mayer',
#  'company believing nfc google nexus nokia also carrier verifone even apple seems sxsw sxswnfc',
#  'mention best thing heard weekend sxsw quot gave ipad 2 money japan relief need ipad 2 quot mention',
#  'ipad 2 better time improve sxsw',
#  'cu pacman google singularity sxsw noobs meetup',
#  'link go beyond earth hour year sharing positive action world download earthhour 60 iphone app sxsw',
#  'far biggest sxsw mistake bringing iphone ipad charger',
#  'google v bing bettersearch bing shot success w structured search potentially higher margin cpa model v google sxsw',
#  'course bing result good google seo sxsw qagb',
#  'mention black white ipad sxsw ipad2 question',
#  'hootsuite blog social medium dashboard hootsuite mobile sxsw update iphone blackberry amp android link',
#  'hootsuite blog social medium dashboard hootsuite mobile sxsw update iphone blackberry amp android link',
#  'hoot new blog post hootsuite mobile sxsw update iphone blackberry amp android link',
#  'anyone bringing ipad v computer sxsw',
#  'impulsive buy friend sxsw gt one selling 1st gen 32gb 3g ipad',
#  'mention buying 2 new ipad mention geekdate apple sxsw ipad2',
#  'someone buying present rt mention apple opening pop store austin sxsw link',
#  'nice find rsq mention link sxsw ipad app',
#  'south southwest panel illustrated pic sometimes best link news ogilvy sxsw trending cyber iphone',
#  'google calendar saturday night giant overlap sxsw party',
#  'quot google canadian tuxedo lose hour quot sxsw',
#  'anyone make cooler rt mention mention launch quot groupon living social type quot reward sxsw link',
#  'exciting wait rt mention apple opening temporary store downtown austin sxsw amp ipad 2 launch link',
#  'great certain meeting rt mention hello holler gram new ipad app link hollergram sxsw',
#  'dont miss charles chen android chromeos access sxsw mention google booth exhibit hall 3 mention 1pm sxsw',
#  'reminder charles chen talking android chromeos access today mention 1pm mention google booth exhibit hall 3 sxsw',
#  'tomorrow charles chen speaking android chromeos access mention google booth exhibit hall 3 mention 1pm sxsw',
#  'group chat apps sxsw told l two apps yet avail android point need phone apps',
#  'remember chime tweet nasatweetup experience 2 15pm 3pm central time sxsw session link',
#  'daily chord tuesday march 8 hacker discover google music servicestory rollin link sxsw music news',
#  'daily chord tuesday march 8 hacker discover google music servicestory rolling stone mo link sxsw',
#  'google circle austin sxsw link',
#  'google circle sxsw link ht mention maybe reconsidering shape',
#  'google circle buzz corner rounded might find today link sxsw google',
#  'google circle rt mention launching product sxsw plenty else',
#  '10 austin classic missed sxsw m4blog com twitter iphone 3 12 11 12 40 pm',
#  'tool collaboration across boundary google webex dropbox whiteboarding basecamp join ipad sxsw evolvingworkplace',
#  'trying collaborate sxsw event friend google calendar plancast',
#  'sxsw come hear speak 40 min designing ipad interface new navigation schema ballrm 11 00am uxdes mention',
#  'ipad 2 coming sxsw guess apple pretty desperate give attention',
#  'coming sxsw sure download sxsw go app schedule location event link',
#  'seriously considering leaving macbook pro home flying solo ipad week think make work sxsw',
#  'among cool goofy thing spied sxsw today ipad case made look like etchnsketch grown game tug war',
#  'wish could mention mention mention party sxsw instead homework tomorrow',
#  'could find mention sxsw probably fiting ipad',
#  'check coyne pr update sxsw link via mention',
#  'crazy look around sxsw realize last year one ipad sxsw',
#  'crazy big crowd sxsw mention apple store sxsw link',
#  'u read article google say rumor mention launch major new social network called circle link sxsw',
#  'sxsw l mention 4 iphone amp come uj booth acc hall 2 snap pic amp send em u fightthepaddle link',
#  'shipment daily follow mention appleatxdt 4 update rt mention pop apple store seems pop ipad2s sxsw',
#  'day 3 tired hold ipad week death happy death sxsw',
#  'beautiful day austin come grab slice two check google get deal sxswi sxsw',
#  'four day ipad sxsw weekend battlela',
#  'iphone dead find secret batphone sxsw',
#  'google debut new selective social network today sxsw mention link google circle',
#  'trying decide session attend sxsw marissa meyer mention later today given',
#  'excellent deck rt mention nth time lucky google new social network launch maybe link sxsw',
#  'quot default state user leisurely contemplative quot mention ipad sxsw',
#  'mobile definitely hot topic year every session standing room next lesson learnt building netflix iphone app sxsw',
#  'apple deliberately chose march 11 ipad 2 availability knowing large chunk customer base sxsw',
#  'google tv demo league extraordinary hacker cool stuff like web apps tv google sxsw lxh',
#  'best ipad design big chunky element generous space clarity trump density tap quality trump tap quantity tapworthy sxsw',
#  'attending designing ipad interface new navigation schema w mention great stuff far sxsw',
#  'attending designing ipad interface new navigation schema akqa lynn teo ballroom yes hiring sxsw',
#  'check designing android sxsw link sxsw uxamandroid',
#  'check designing ipad interface new navigation schema sxsw uxdes',
#  'check designing ipad interface new navigation schema sxsw link sxsw uxdes',
#  'headed designing ipad interface new navigation schema sxsw link sxsw uxdes',
#  'taking designing ipad interface new navigation schema sxsw link sxsw uxdes',
#  'adobe developed engine essentially convert swf file jquery html5 existing flash file portable ipad sxsw',
#  'developer awesome name event rt mention join league extraordinary h4ckers sxsw link',
#  'behaviour diff lot phone call using ipad laptop notsomuch mobile internet sxsw',
#  'lovin digital mention band sings iphone amp play guitar app fan record vids ipad2s cnn digital cnngrill sxsw sxswi',
#  'barry diller think ipad content nut mention sxsw mention link mention',
#  'really need another big social network right thanks sxsw google link',
#  'q2 u think google check offer testing sxsw link smccolumbus',
#  'japan docomo introduced mobile apps six year apple came app store jpmobilesummit sxsw',
#  'time apple store sxsw open pulling ipad2 trigger',
#  'sxsw forget come privacybootcamp startup mention mention mention mention link',
#  'sxsw forget come privacybootcamp startup mention mention mention mention acc 9abc 3 30 cst',
#  'bad button rt mention know sxsw time abnormal amount app update iphone',
#  'web devs wait line ipad 2 sxsw signup new relic using promo sxsw2011 eligible win one link',
#  'mention download 20 free track sxsw music sampler available mention store today link',
#  'mention download 20 free track sxsw music sampler available mention store today link',
#  'mention download 20 free track sxsw music sampler available mention store today link fb',
#  'mention downloadfree track sxsw music sampler available mention link green lady killer',
#  'guess drew bigger crowd sxsw mention chimp could work iphone sorry mention',
#  'jeez guy dunno apple pop gold gym u realize un job aesthetic sxsw apple',
#  'anyone else using hashable network sxsw week trying android version',
#  'enjoy sxsw ride anywhere austin 10 download groundlink app link booth 437',
#  'enjoy sxsw ride anywhere austin 10 dwnld groundlink app link booth 437',
#  'even begin apple winning sxsw link via mention mention',
#  'even begin apple win sxsw link tc apple',
#  'even begin apple win sxsw link mention',
#  'even begin apple win sxsw link opening temporary store downtown austin support ipad2 launch genius',
#  'even begin apple win sxsw past week major dilemma link',
#  'even begin apple win sxsw techcrunch link ipad',
#  'even begin apple win sxsw link',
#  'even begin apple win sxsw link',
#  'even begin apple win sxsw link',
#  'even begin apple win sxsw link mention mention',
#  'even begin apple win sxsw link via mention mention mention',
#  'even begin apple win sxsw link mention',
#  'even begin apple win sxsw link via mention',
#  'even begin apple win sxsw link gt gon na get sum via mention',
#  'even begin apple win sxsw techcrunch link sxsw',
#  'even begin apple win sxsw link lt lt win big sxsw',
#  'even begin apple win sxsw link apple ipad2 pm sxsw',
#  'even begin apple win sxsw link apple ipad2 sxsw tc',
#  'even begin apple win sxsw link apple sxsw',
#  'even begin apple win sxsw link tc apple ipad2 sxsw',
#  'even begin apple win sxsw link via mention apple sxsw',
#  'even begin apple win sxsw link via mention mention apple sxsw',
#  'badgeless event free drink mention heading free google sponsored happy hour semantic web austin mention fogo de ch sxsw',
#  'best swag ever thanks mention charging iphone thanks sxsw link',
#  'thanks everyone making great day shop today austin come see u tomorrow link sxsw',
#  'thanks everyone came today good luck winning ipad stop tomorrow chance win sxsw',
#  'timing everything ipad 2 brand winner sxsw mention link pnid sxsw',
#  'hey sxsw exhibitor capture booth experience retrollect disc popular disc win ipad 2 link',
#  '4sq see facebook google competition via mention checkins sxsw',
#  'sxsw fantastic schedule app iphone bummer still crackberry',
#  'photo far best sxsw accessory ipad followed closely margarita link',
#  'one fav photo sxsw far mention amp mention google sxsw link',
#  'watch fb 4 big brother rt google launch major new social network called circle possibly today link sxsw',
#  'think fell bit love google today thanks throwing nerd party speakeasy sxsw',
#  'way figure ipad 2 good replacement making sxsw year',
#  'dslr film discussion moderated guy kawasaki apple fame packed house sxsw',
#  'get sxsw film red carpet coverage mention cw austin star mandy dugan grouped get app link',
#  'need find better sxsw stream follow inane ipad 2 tweet surely southby',
#  'mention find stupid stupid game ipad currently special sxsw sale link',
#  'rt find hottest spot mention w mention hot spot sxsw app wp7 link iphone link',
#  'trying find apple pop store sxsw widfy',
#  'first person queue new apple store austin may sxsw link',
#  'technews flipboard add instagram photo social search apps link tech news apple social search sxsw tech',
#  'il ceo di flipboard annuncia la versione iphone mention mention next platform flipboard iphone team started working sxsw',
#  'google focusing bridging digital physical divide eg map streetview hotpot amp autonomous driving sxsw mention',
#  'hey sxsw folk please keep u posted google circle hope blast link',
#  'hey sxsw folk free lunch la condesa pepsi max lot map link',
#  'apple follow customer sxsw forbes link alcoholic call enabling rest u call genius',
#  'please rt follow next big college social network mention chance win ipad 7 000 follower socialmedia sxsw',
#  'gear list sxsw music iphone vzw blackberry sprint ipad jambox hp elitebook lacking good portable headphone suggestion',
#  'preparing sxsw talk google doodle mention fun friday 5pm link',
#  'good news austin bound apple fanboys link sxsw ipad2',
#  'saving ipad2 photo apple store sxsw link mention mention mention mention jerranalley tbalinas',
#  'wish list tech ntn sxsw google apps help level playing field kid may software home',
#  'designing ipad catch mention matt carlson amp mention matthew davis sxsw mon 9 30 hilton link',
#  'hitlantis ipad cool song explorer app hitlantis com sxsw musicviz',
#  'searching temporary apple store sxsw',
#  'thank rt mention public note quot 5 step bulletproof ux strategy quot link sxsw rhjr ux5 via mention',
#  'queue forming austin sxsw pop apple store link guy front since 5am apparently',
#  'frankenstein amalgamation fragmented digital identity becoming anti schizophrenic google ai sm sci fi sxsw',
#  'want free music free sxsw sampler album itunes download link open itunes link',
#  'free 22 song sampler available download itunes artist playing sxsw check link music',
#  'quot win free ipad 2 webdoc com sxsw rt quot',
#  'grab free music sxsw 2011 showcasing artist mp3 torrent wild link sxsw',
#  'hey sxsw friend anyone iphone charger mention borrow tonight lmk',
#  'friend sxsw willing pick ipad pay premium dm sxsw atl link',
#  'good talk akqas mention ipad interface w callback design principle wish go beyond medium marketing example fb sxsw',
#  'person front took picture new ipad sxsw',
#  'tessie frontwoman intimate stranger ink painful place get ink respect location link sxsw',
#  'quot future local contextual discovery quot google marissa mayer argues exceptionally valuable type search sxsw',
#  'quot future touch user interface design quot wondering presentation microsoft employee mention ipad sxsw',
#  'sxsw geek game compete gain vip status amp win big prize know link mashable geek game sxsw cyber iphone',
#  'mention gearing make splash mention launch quot groupon living social type quot reward sxsw link boom',
#  'zazzle gearing hit sxsw look tweet come create iphone case zazzlesxsw',
#  'marketing genius apple open pop store outside sxsw link',
#  'mention get look sxsw rumored apple quot pop quot store austin link',
#  'trying get google 80 retro party maggie mae line huge hope worth wait sxsw sxsw2011',
#  'mention get ready word quot circle quot trending sxswi sxsw google circle social',
#  'sxsw get soundcloud iphone app link start recording use 4sq geotagging map link',
#  'get food forget snap photo win macbook air ipad 2 apple tv sxsw',
#  'austin getting full sxsw underway tell iphone intermittent brick crowded',
#  'google give social networking another try quot circle quot via mention mention link sxsw',
#  'amp giving away amazing prize iphone android kindle tablet amazing happening sheraton sxsw',
#  'zaarly giving away ipad 2 sxsw person beta signup referral link craigslistkiller',
#  'google giving free google lab laptop open source coder r attending meet sxsw got cupcake',
#  'sxsw go app available blackberry window 7 addition iphone ipad android link',
#  'need go sxsw 7 mo old sitter know score apple martin like babyheadphones',
#  'go sxsw next year rt mention apple open temporary store sxsw link',
#  'want go apple pop store afraid leave new ipad sxsw',
#  'hey sxsw goer droppin survival tip week help get rock best hangover cure tamale house 3 link',
#  'bomb go convention center apple going lose devastating share customer base sxsw',
#  'omg going sxsw macbook pro ipad iphone4 ipod galaxy tab techgeek',
#  'going sxsw want talk html cs catch mention google webmaster team',
#  'going see mention tonight link sxsw',
#  'golden ticket f 4sq party day real party redbullbpm felix da housecat playing ipad sxsw link',
#  'good morning 2 u enjoy sxsw ride anywhere austin 10 dwnld groundlink app link booth 437',
#  'queue google er bing talk spam ridiculous busiest seen sxsw',
#  'haha google quot party like 1986 quot party link sxsw',
#  'gsd amp google sxsw party mention blowing mind much amazing food drink music amp photo booth fun',
#  'sxsw google authenticator app mobile device step ahead',
#  'mention google circle first real alternative facebook sxsw',
#  'google circle launch link quot may good timing given twitter sxsw',
#  'mention google place value domain extension equal sxsw qagb',
#  'attending google keynote seeing google map mobile feature sxsw',
#  'quot google name built getting thing trying quot marissa mayer sxsw frm mention',
#  'mention google let block site stand link sxsw blocking look like need',
#  'length google penalty based severity breach webmaster guideline e white text white bgr might get 30 day pen sxsw qagb',
#  'mention google set launch new social network circle today sxsw mention mention',
#  'need google lonelyboy15 mention talk time sxsw enchantment',
#  'mention google launch major new social network called circle possibly today updated happen sxsw link',
#  'mention google launch major new social network called circle possibly today link sxsw',
#  'mention google launch major new social network called circle possibly today link sxsw something keep watch',
#  'mention google launch major new social network called circle possibly today link sxsw never beat myspace',
#  'mention google launch major new social network called circle possibly today link sxsw mention',
#  'mention google launch major new social network called circle possibly today link sxsw mention bigger gaga',
#  'mention google launch major new social network called circle possibly today link sxsw fb',
#  'mention google launch major new social network called circle possibly today link sxsw hnwsxsw',
#  'mention google launch major new social network called circle possibly today link sxsw goog',
#  'mention google launch major new social network called circle possibly today link sxsw dejavu',
#  'mention google launch major new social network called circle possibly today link sxsw sta nije im dosta gbuzz',
#  'mention google launch major new social network called circle possibly today link sxsw te dije wey mention',
#  'mention google launch major new social network called circle possibly today link sxsw super interesting',
#  'mention google launch major new social network called circle possibly today link rt mention sxsw',
#  'mention google launch major new social network called circle possibly today sxsw link sxsw nfusion hmm',
#  'mention google launch new social network called circle today link sxsw applause new privacy model attempt',
#  'technews google launch new social network sxsw link tech news aclu sxsw tech',
#  'breaking google launch major new social network called circle today link via mention sxsw socialmedia',
#  'diller google tv quot first product good consumer product basically quot sxsw diller',
#  'mention google connect digital amp physical world mobile link sxsw rt mention',
#  'mention google connect digital amp physical world mobile link sxsw rt mention',
#  'sxsw google apple ea game zynga facebook microsoft intuit went gaga go game link',
#  'future google contextual discovery location context help u go deeper ever search without search mention sxsw',
#  'mention google cutts say reputation topicality 2 key matter site ranking qagb sxsw saying trust amp lda',
#  'google marissa mayer talk 3 30 worth going sxsw',
#  'ironic googled direction mention party ended walked 6 block wrong direction time bed think sxsw',
#  'check googletv ipad apps connected tv experience sxsw link sxsw connectedtv',
#  'check googletv ipad apps connected tv experience sxsw link sxsw connectedtv fascinating',
#  'cnnmoney got craving sxsw mind created app foodspotting link iphone apps',
#  'microsoft got drunk changed iphone default search yahoo sxsw',
#  'mention grab latest mention sxsw link saytextson',
#  'msc page guy get tattoo sxsw could win free ipad2 link sxsw tattoo ipad link allshare',
#  'bring guy start austin mention mention touchingstories sxsw quot designing digital magazine ipad quot',
#  'le half hour tell win ipad 2 rt sxsw sxswi',
#  'ipad 2 hand awesome dude gave cutsies 3 hour line austin apple sxsw winning',
#  'ipad 2 hand sxsw thisisdare',
#  'gon na hang ipad hacked nook around neck week become flava flav sxsw top hipster gsdm',
#  'mention something called google place hotpot work recommendation engine sxsw',
#  'post nothing sxsw link',
#  'smtravel heard google plan launch socnet may quot circle quot learned lot 5 year lot changed via sxsw',
#  'bb discriminatory p rt mention mention officially sxsw come fc grill amp make ur iphone case',
#  'may invite quot cool quot sxsw sxswi party two iphone charger pocket happy see',
#  'would thunk rt mention agency push google direction never would gone otherwise say mention sxsw',
#  'mention yet see someone pc dell otherwise mention sxsw apple macbook pro ipads sxsw b soon',
#  'meeting line sxsw popup apple store ipad2 love place',
#  'apple hawk ipad 2 sxsw festival popup store link mention',
#  'want hear mention tell google love story connectedbrands sxsw sxswic',
#  'pumped hear mention dude talk logo year make one sxsw gsdm',
#  'thanks heathcare digital mention publishing news new medical apps showcased sxsw link sxswh',
#  'hello enjoy sxsw ride anywhere austin 10 download groundlink app link booth 437',
#  'oh lordy go rt mention time apple store sxsw open pulling ipad2 trigger',
#  'mention hey austin know little iphone android love music amp wan na make 20 hour sxsw please let know',
#  'loved honesty google marissa mayer keynote many product need step customer service location sxsw',
#  'google host developer day sxsw link sxsw mention',
# ...
#  'google launch major new social network called circle google circle sxsw link',
#  'google launch major new social network called circle google circle sxsw link',
#  'google launch major new social network called circle link sxsw v mention mention',
#  'google launch new social network sxsw link google sxsw',
#  'google launch new social network sxsw cnet news link sxsw',
#  'google launch new social network sxsw link aclu sxsw',
#  'google launch new social network called circle possibly today link link sxsw',
#  'google launch new social network circle linking u closely peep u connect w possibly today mention sxsw',
#  'google launch new social portal today sxsw link',
#  'google launch product wait launch product exists wait product exist sxsw link',
#  'google launch social network quot circle quot denies launch sxsw though link google circle',
#  'google launch social network called circle sxsw rt',
#  'google launch social network google circle point sxsw today link sxsw',
#  'google launch social network today mention sxsw update status share video amp photo circle friend link',
#  'hootsuite launch new analytics integrates facebook google analytics look good hootsuite sxsw link hootstats',
#  'google launching new social network called circle today sxsw link',
#  'google launching social network definitely sxsw rumor still link googlecircles',
#  'launching product sxsw plenty else join u h4ckers amp 80 dancing today link',
#  'wikitude layar flar tool argon google goggles augmented reality browser tool amp apps check sxsw eduar',
#  'lazy google sxsw',
#  'hope leave sxsw rt mention apple opening pop store austin sxsw link mention',
#  'check left brain search google right brain search x sxsw link sxsw bettersearch',
#  'check lightbox com team android choice award finalist announced sxsw mention team rock',
#  'god like sxsw imac macbook iphone blackberry staring enough time read book remember',
#  'smell like cheese stick rt mention quot ipad dj working etsy party quot realtalk sxsw',
#  'ha seems like gt mention news sxswi apple temporary ipad store sxsw wth',
#  'line sxsw apple store ipad',
#  'line sxsw apple store ipad day 2 link',
#  'anyone line temporary apple store austin idea till late open tonight sxsw',
#  'people line ipad 2 passing time surfing ipad 1 sxsw',
#  'saw giant line thought movie premiere apple store ipad 2 heard scream premiere sxsw',
#  'line temp apple store austin yet sxsw',
#  'list music performer sxsw link used jquery screen scrape',
#  'people listening google sxsw mention link',
#  'since listening google marissa mayer engaging twitter wondering heck happened google buzz sxsw',
#  'location location location link via mention google sxsw',
#  'tech one lone dude awaits ipad 2 apple sxsw store apple likely expected bigger crowd forming link technology',
#  'bet longest ipad line gon na austin sxsw',
#  'getting look google impact dashboard first time sxsw',
#  'google looking social signal search result qagb sxsw',
#  'looking hig like guideline designing android link adam beckley uxamandroid mention sxsw',
#  'looking forward google bing q website ranking week sxsw',
#  'radio 3 0 looking new band radio show listen link link nowplaying newmusic sxsw pls rt',
#  'anyone lost iphone cab downtown austin last night please hit sxsw',
#  'anyone lost iphone back cab downtown austin around 10 30 11p tonight please hit sxsw',
#  'lot drinking amp drawing google sketchup party sxsw',
#  'lot google effort helping japan many global issue rt mention rt mention wtf w people sxsw',
#  'got ta love mention mention unabashed apple fanboy gt gt even begin apple win sxsw link',
#  'geeky love rt mention apple opening temporary store downtown austin sxsw ipad 2 launch link',
#  'mention love mention mention sxsw quot apple come w cool technology one ever heard go 2 conference quot 2',
#  'mention love mention sxsw quot apple come cool technology one ever heard go conference quot',
#  'n33 love town link code valid 12 00 3 59 59p 03 14 11 infektd sxsw necro',
#  'sketchily lurking mention big boi sxsw concert iphone business 8am hard read massive announcement deadline lovemyjob mention',
#  'trying make detailed colour coded google calendar sxsw proving really tough also get organized',
#  'technews man panhandling ipad 2 sxsw world coming link tech news ipad 2 sxsw tech',
#  'quot many people ipads quot whole room raise hand quot ipad 2 quot half room raise hand stillonamacbook shame sxsw nfusion',
#  'rt hiring marketer designer creatives social medium pro come see aquent booth 1415 sxsw trade show might win ipad 2',
#  'love marketing genius sxsw rt mention inside apple temporary store austin link',
#  'great vid marty rt mention ipad2 live unboxing front sxsw apple store video link',
#  'think may go ipad laptop today sxswi sxsw veteran reason',
#  'made soundcloud ambassador sxsw upload music show amp reward rt mention soundcloud android app fresh',
#  'come find mention booth 2 mention ipad case left 1 mention win cbatsxsw sxsw',
#  'amazes many people tuck flap apple ipad case sxsw',
#  'omfg mean please link webber ipad sxsw dionne warwick',
#  'alert medium saw one android tablet sxsw like finding needle haystack also saw cr 48',
#  'n2 first meeting link code valid 12 00 3 59 59p 03 11 11 infektd sxsw necro',
#  'great meeting haha hollergram link sxsw',
#  'great mental image rt mention people session taking photo w ipad 2 air doingitwrong sxsw',
#  'purchased mexican mavis boy amp bear sold first listen thanks sxsw link itunes',
#  'purchased mexican mavis boy amp bear sold first listen thanks sxsw itunes free link itunes',
#  'think might go weekend without seeing ipad case twice sxsw',
#  'sure mine via ipad rt mention know agnerd dairy relies evernote link sxsw agchat',
#  'bummed miss sxsw year quarantined kiddie cold garageband ipad comfort fb',
#  'miss knew spotted nfc enabled google place marker bird wonder billboard near sxsw link',
#  'red 7 mist giant dope interviewed adi mind adi minute ago compared cat pic sxsw location link',
#  'hootsuite mobile sxsw update iphone blackberry amp android link',
#  'hootsuite mobile sxsw update iphone blackberry amp android link via mention',
#  'hootsuite mobile sxsw update iphone blackberry amp android link android blackberry keitai',
#  'hootsuite mobile sxsw update iphone blackberry amp android link hootsuite',
#  'hootsuite mobile sxsw update iphone blackberry amp android link via mention',
#  'hootsuite mobile sxsw update iphone blackberry amp android shared paul link shared',
#  'hootsuite mobile sxsw update iphone blackberry amp android whether getting friendly link',
#  'mashup mobile contextual information future google marissa mayer sxsw thefutureismobile',
#  'pat sxsw know talking please google julia sweeney learn',
#  'well good morning sxswi day 4 ready another day great panel bc alumnus amp industry party tonight sxsw gsdm google',
#  'loving morphie juicepack today recharge iphone worth sxsw',
#  'brilliant move apple even begin apple win sxsw link',
#  'hey sxsw mover shaker mention publishing quot poke box quot ebook next week get involved link',
#  'much fun handing chance win 2 audi car mention sxsw mention apple store sxsw link',
#  'could murphy usa better serve inside google map phone google announcing great feature v5 sxsw',
#  'ipad intimate together tapworthy designflaws sxswi sxsw',
#  'compiling sxsw list one google doc taking lot longer thought many party many good musician',
#  'day 1 charger kicked bucket heck apple store within walking distance sxsw',
#  'sxsw good deed returned lost iphone',
#  'thanks good friend great mention gifting exogear iphone backup battery case priceless sxsw',
#  'sent iphone rt mention behind 100 email give 1 line iphone composed reply sxsw protip',
#  'iphone ipad feel unequipped compared everyone else dang sxsw',
#  'headed sole sxsw event aclu dotrights google party',
#  'whats name song link imthetype ipad imthetype sxsw',
#  'need quot page flip effect quot like fake needle cd player tapworthy sxsw ipad',
#  'hm need another 1 rt mention google launch major new social network called circle possibly today link sxsw',
#  'u need mention group challenged coming iphone app solve parenting issue sxsw worklifeprogress',
#  'mention need help badass android developer right debugging emergency know anyone mention sxsw',
#  'mention new ubersocial iphone app store includes uberguide sxsw sponsored mashable link',
#  'mention new ubersocial iphone app store includes uberguide sxsw sponsored mashable link fin ly',
#  'mention new ubersocial iphone app store includes uberguide sxsw sponsored mashable mention vamos probar',
#  'couple new blog random tip awesome iphone app dev link politics behind html5 link sxsw',
#  'news industry spending r amp wait apple innovate publisher b c print subsidizing effort newsapps sxsw',
#  'hootsuite news hootsuite mobile sxsw update iphone blackberry amp android link',
#  'dude next holding using ipad 2 like trophy sxsw lookingforwardtothemusicfest',
#  'nice mention store huh chance meet face face sxsw today sat wan na talk beer amp social',
#  'hard feeling towards google mention say would make great partner checkins sxsw pnid',
#  'mention 1 hack found people jumping corporate firewall e g using google doc etc hackingwork sxsw',
#  'hope flop akabuzz mention google launch major new social network called circle possibly today link sxsw',
#  'c34 retreat link code valid 12 00 3 59 59p 03 14 11 infektd sxsw cvdc',
#  'mention rumor apple popup store downtown austin sxsw amp ipad 2 launch link smart move 1of many dfcbto',
#  'anyone hopping groupon bandwagon mention launch quot groupon living social type quot reward sxsw link',
#  'google launching product sxsw link',
#  'google launching anything sxsw partying link circle',
#  'droid surprised rt mention spotted sxsw table three people 8 phone ipad macbook gadgetoverload',
#  'buy buy rt mention even begin apple win sxsw link',
#  'farooqui mobile io android catching fast grow allow app purchasing gamesfortv sxsw',
#  'fear extended wed gt rt mention rt mention last day apple popup sunday 3 13 sxsw appleatxdt',
#  'calvin geek charlie sheen goddess mention mention mention mention google sxsw',
#  'mention mention quot getting feedback sxsw group amp pushed android fix grilled cheese stand yesterday quot',
#  'mention mention manufacturing serendipity quot access information make u curious le quot sxsw',
#  'quot sxsw nothing teeming sea iphone addict busy twittering ever engage one anoth cont link',
#  'fan new sxsw trend audience sharing opinion via holding ipad listen annoying',
#  'quot 40 google map usage mobile quot marissa mayer sxsw',
#  'power apple people spent hundred dollar attend sxsw spending day waiting line ipad',
#  'continuum attitude crowdsourcing gap quot hear quot apple quot tell quot sxsw',
#  'google vp consumer product marissa mayer say location everything link sxsw',
#  'sxsw 20 google search local information marissa mayer 6 million place claimed owner logged google',
#  'third era google logo interactive play space get ready googledoodle sxsw gsdm',
#  'new batch ipad 2 delivered sxsw ipad2 mention apple store sxsw link photo',
#  'highlight day undoubtedly meeting mention google 30 second softball fancrazed preso sxsw',
#  'cool team startup came via siliconvalley bus hacking apps mention ex google au stage w speakermeetup sxsw dogpatch lab',
#  'wow lot sxsw audience seen 3d vector panning google map mobile gasp appreciation',
#  'sxsw tip day turn iphone screen brightness way conservebatterylife peace mention',
#  'first leg mobile social sxsw fb link',
#  'i14 call zombie link code valid 4 00 7 59 59p 03 12 11 infektd sxsw zomb',
#  'i18 call zombie link code valid 8 00 11 59 59p 03 12 11 infektd sxsw zomb',
#  'tomlinson tx observer say apple subscription data holding biggest impediment success newsapps sxsw',
#  'tip turn push amp set fetch manual mode email mail contact amp cal gt fetch new data save battery iphone sxsw',
#  'mention official sxsw app sxsw go link android iphone ipad lt thanks installed',
#  'zazzle officially sxsw come mention grille mention u zazzlsxsw get make iphone case',
#  'technews omg jk kiss ipad 2 slap xoom link tech news ipad 2 jk omg sxsw tech',
#  'mention sxsw cr48 much potential link',
#  'idle time sxsw friday expensive thing mention apple store sxsw w 80 others pic link',
#  'also android rt mention foodspotting hit iphone app find food crave link cnnmoneysxsw sxsw',
#  'usa today ipad make good use digital shortcut still looking like newspaper mention tapworthy sxsw',
#  'iphone one hand caramel macchiato ouch hiss hot apparently two pump lava begin sxsw tmsxsw',
#  'thats one want get hit canada rt mention sxsw ipad store sold everything except 64gig wifi white',
#  'technews one lone dude awaits ipad 2 apple sxsw store link tech news apple ipad 2 sxsw tablet tech',
#  'one million rating per month google hotpot sxsw pr',
#  'haz one mention showed mention charge anywhere bar charge iphone whole table wanted buy one sxsw',
#  'quot explanation continued success apple existence god quot mention enchantment sxsw',
#  'apple open quot pop quot store across street sxsw two week umm genius obvious cough ipad2 cough',
#  'apple open pop store sxsw time ipad2 sale link',
#  'apple open pop shop sxsw report link',
#  'apple open pop shop sxsw report link via mention',
#  'apple open pop shop sxsw report link property',
#  'apple open pop shop sxsw report apple set open temporary store link',
#  'apple open pop shop sxsw report apple set open temporary store link realestate tech',
#  'apple open pop shop sxsw link via mention',
#  'apple open pop shop sxsw link',
#  'apple open pop shop sxsw link lt cool concept spend sxsw waiting ipad2',
#  'apple open temporary store sxsw link',
#  'open time tues amp wed news site manager want chat google news let know sxsw',
#  'wear openbeta vip badge sxsw might win ipad quibids case mention sxswbuffalo',
#  'apple opened makeshift store sxsw ipad2 available 5pm today tempted',
#  'launching iphone app soon participating launchrock comp sxsw link get invite',
#  'hey sxsw new ipad app dexteria available link like u facebook link',
#  'ipad 2 plenty people store line scarfing sxsw mention apple store sxsw w 65 others link',
#  'nice line outside sxsw apple store guess people want ipad2s',
#  'confusion google circle google claim circle released sxsw even development link',
#  'packing point showing iphone fragmentation sxsw',
#  'attending panel quot better living cloud computing quot presented google jon wiley sxsw',
#  'one sxsw panel moderator europe say spent 3000 roaming charge iphone sxsw 2010',
#  'brown paper window line grows sxsw popup apple store gold gym sixth amp congress link',
#  'sxsw two party awesome journalism npr google one go pb',
#  'google party best ever get butt sxsw',
#  'hey sxsw peep new iphone app voicefeed launched u link check let u know think',
#  'watch people interact information different bigger smaller touchingstories ipad tablet sxsw',
#  'hey sxsw people survival tip 2 great vegitarian vegan right think action mr natural link sxswsurvival',
#  'sxsw pepsi max marketing street team shown popup apple store line handing drink amp tshirts link',
#  'new post per rumor google may preview big social strategy 80 themed costume party sxsw yep link',
#  'instagram photo iamtimbaker google 1980 sxsw party mention link',
#  'trying pick theme sxsw year think may opening data google government sxsw bolinsxsw',
#  'google planning launch major new social network called circle preview far super positive sxsw link',
#  'mashable platform concertgoers launch android app time sxsw link sxsw link',
#  'game play swsx spot non apple electronics sxsw',
#  'need play game android sxsw link',
#  'grown men playing lego google party sxsw mention speakeasy link',
#  'left pocket guide hotel know going cope say usability ipad iphone app sxsw',
#  'check poked liked amp tweeted google love story sxsw link sxsw sxsw15 sxswic',
#  'check poked liked amp tweeted google love story sxsw sxsw sxsw15 sxswic',
#  'temporary pop shop apple sxsw nice flipboard upgrade',
#  'apple pop store sxsw joke',
#  'found pop apple store sxsw',
#  ...]

# %%
tokenized_sents = [word_tokenize(i) for i in lemmatized_output]

# %%
model = Word2Vec(tokenized_sents, size=100, window=5, min_count=1, workers=4)

# %%
model.train(lemmatized_output, total_examples=model.corpus_count, epochs=10)
# Out:
# (4208313, 6762560)

# %%
wv = model.wv

# %%
wordlist = list(model.wv.vocab)

# %%
wordlist
# Out:
# ['wesley83',
#  '3g',
#  'iphone',
#  '3',
#  'hr',
#  'tweeting',
#  'rise',
#  'austin',
#  'dead',
#  'need',
#  'upgrade',
#  'plugin',
#  'station',
#  'sxsw',
#  'know',
#  'fludapp',
#  'awesome',
#  'ipad',
#  'app',
#  'likely',
#  'appreciate',
#  'design',
#  'also',
#  'giving',
#  'free',
#  't',
#  'wait',
#  '2',
#  'sale',
#  'hope',
#  'year',
#  'festival',
#  'crashy',
#  'great',
#  'stuff',
#  'fri',
#  'marissa',
#  'mayer',
#  'google',
#  'tim',
#  'reilly',
#  'tech',
#  'book',
#  'conference',
#  'amp',
#  'matt',
#  'mullenweg',
#  'wordpress',
#  'new',
#  'apps',
#  'speechtherapy',
#  'communication',
#  'showcased',
#  'iear',
#  'edchat',
#  'asd',
#  'nan',
#  'starting',
#  'ctia',
#  'around',
#  'corner',
#  'googleio',
#  'hop',
#  'skip',
#  'jump',
#  'good',
#  'time',
#  'android',
#  'fan',
#  'beautifully',
#  'smart',
#  'simple',
#  'idea',
#  'rt',
#  'madebymany',
#  'thenextweb',
#  'wrote',
#  'hollergram',
#  'counting',
#  'day',
#  'plus',
#  'strong',
#  'canadian',
#  'dollar',
#  'mean',
#  'stock',
#  'apple',
#  'gear',
#  'excited',
#  'meet',
#  'samsungmobileus',
#  'show',
#  'sprint',
#  'galaxy',
#  'still',
#  'running',
#  '1',
#  'fail',
#  'find',
#  'start',
#  'impromptu',
#  'party',
#  'hurricaneparty',
#  'til',
#  'come',
#  'foursquare',
#  'ups',
#  'game',
#  'prefer',
#  'gowalla',
#  'far',
#  'best',
#  'looking',
#  'date',
#  'got',
#  'ta',
#  'love',
#  'calendar',
#  'featuring',
#  'top',
#  'case',
#  'check',
#  'hamsandwich',
#  'via',
#  'ischafer',
#  'gt',
#  'haha',
#  'awesomely',
#  'rad',
#  'holler',
#  'gram',
#  'itunes',
#  'store',
#  'marc',
#  'ken',
#  'noticed',
#  'dst',
#  'coming',
#  'weekend',
#  'many',
#  'user',
#  'hour',
#  'late',
#  'sunday',
#  'morning',
#  'added',
#  'flight',
#  'planely',
#  'matching',
#  'people',
#  'plane',
#  'airport',
#  'downloaded',
#  'klm',
#  'nicely',
#  'done',
#  'must',
#  'malbonster',
#  'lovely',
#  'review',
#  'forbes',
#  'buy',
#  'ipad2',
#  'sure',
#  'q',
#  'oh',
#  'god',
#  'pure',
#  'unadulterated',
#  'easier',
#  'browse',
#  'event',
#  'website',
#  'okay',
#  'really',
#  'yay',
#  '11',
#  'kthxbai',
#  'photo',
#  'installed',
#  'nice',
#  'enjoying',
#  'change',
#  '0',
#  'forward',
#  'seeing',
#  'else',
#  'sleeve',
#  'laurieshook',
#  'smcdallas',
#  'pre',
#  'wed',
#  'hoping',
#  'win',
#  'resulting',
#  'shameless',
#  'promotion',
#  'chevysmc',
#  'michaelpiliero',
#  'someone',
#  'started',
#  'partnerhub',
#  'group',
#  '4sq3',
#  'look',
#  'like',
#  'going',
#  'rock',
#  'update',
#  'push',
#  'tonight',
#  'keepaustinweird',
#  'right',
#  'sweeeeet',
#  'job',
#  'team',
#  'may',
#  'leave',
#  'vuvuzela',
#  'home',
#  'attn',
#  'frineds',
#  'mention',
#  'register',
#  'gdgtlive',
#  'see',
#  'cobra',
#  'iradar',
#  'link',
#  'anyone',
#  'want',
#  'sell',
#  'old',
#  'bought',
#  'older',
#  'oooh',
#  'launch',
#  'major',
#  'social',
#  'network',
#  'called',
#  'circle',
#  'possibly',
#  'today',
#  'ha',
#  'first',
#  'line',
#  'quot',
#  'pop',
#  'planner',
#  'eventprofs',
#  'pcma',
#  'engage365',
#  'spin',
#  'play',
#  'concept',
#  'music',
#  'discovery',
#  'com',
#  'false',
#  'alarm',
#  'probably',
#  'ever',
#  'vatornews',
#  'force',
#  'print',
#  'medium',
#  'evolve',
#  'weather',
#  'greet',
#  'sweater',
#  'night',
#  'putting',
#  'flash',
#  'downtown',
#  'hootsuite',
#  'mobile',
#  'blackberry',
#  'whether',
#  'getting',
#  'friend',
#  'hey',
#  'long',
#  'think',
#  'take',
#  'u',
#  'make',
#  'answer',
#  'using',
#  'zazzlesxsw',
#  'one',
#  'mashable',
#  'video',
#  'gadget',
#  'pad',
#  'ubersocial',
#  'includes',
#  'uberguide',
#  'sponsored',
#  'smartcover',
#  'open',
#  'instant',
#  'access',
#  'waited',
#  'get',
#  'hand',
#  'held',
#  'hobo',
#  'drafthouse',
#  'shotgun',
#  'hooray',
#  'opening',
#  'orly',
#  'set',
#  'wooooo',
#  'midnight',
#  'khoi',
#  'vinh',
#  'say',
#  'conde',
#  'nast',
#  'headlong',
#  'rush',
#  'publishing',
#  'fundamental',
#  'misunderstanding',
#  'platform',
#  'lt',
#  'help',
#  'doc',
#  'anonymous',
#  'account',
#  'techie',
#  'ppl',
#  'jam',
#  'libya',
#  'musedchat',
#  'sxswi',
#  'classical',
#  'newtwitter',
#  'location',
#  'based',
#  'fast',
#  'fun',
#  'future',
#  'connect',
#  'digital',
#  'physical',
#  'world',
#  'talking',
#  'effort',
#  'allow',
#  'system',
#  'bettercloud',
#  'tweet',
#  'speak',
#  'mark',
#  'belinsky',
#  '911tweets',
#  'panel',
#  '1st',
#  'stop',
#  'chaos',
#  'hunt',
#  'java',
#  'spy',
#  '4',
#  'chance',
#  'pic',
#  'guy',
#  'kawasaki',
#  'talk',
#  'enchanted',
#  'internet',
#  'futuremf',
#  'spec',
#  'recipe',
#  'web',
#  'search',
#  'omfg',
#  'heard',
#  'already',
#  'smile',
#  'would',
#  'lot',
#  'interesting',
#  'actually',
#  'popped',
#  'insane',
#  'agree',
#  'fiona',
#  'town',
#  'somebody',
#  'kidnap',
#  'put',
#  'recording',
#  'studio',
#  'record',
#  'album',
#  'wan',
#  'na',
#  'drink',
#  '7pm',
#  'fado',
#  '4th',
#  'join',
#  'attending',
#  'headache',
#  'boooo',
#  'flipboard',
#  'developing',
#  'version',
#  'power',
#  'value',
#  'service',
#  'battle',
#  'fatigue',
#  'pnid',
#  'chilcott',
#  'stand',
#  'blogger',
#  'staff',
#  'competition',
#  'mentioning',
#  'shirt',
#  'w',
#  'band',
#  'food',
#  'art',
#  'ice',
#  'cream',
#  'nifty',
#  'interactive',
#  'map',
#  'promise',
#  'groupon',
#  'reward',
#  'type',
#  'finger',
#  'crossed',
#  'news',
#  'yahoo',
#  'loosing',
#  'traffic',
#  'site',
#  'doubt',
#  'last',
#  'tho',
#  'weird',
#  'name',
#  'holla',
#  'butt',
#  'phone',
#  'worship',
#  'droid',
#  'mac',
#  'agnerd',
#  'confession',
#  'laptop',
#  'follow',
#  'launching',
#  'denies',
#  'debut',
#  'despite',
#  'report',
#  'post',
#  'easy',
#  'behaving',
#  'crash',
#  'yesterday',
#  'ridiculous',
#  'popup',
#  'peek',
#  'space',
#  'slated',
#  'tomorrow',
#  'thing',
#  'earth',
#  'face',
#  'company',
#  'sxwsi',
#  'stay',
#  'tune',
#  'showcase',
#  'h4ckers',
#  'thank',
#  'touchingstories',
#  'preso',
#  'deck',
#  'thanks',
#  'trying',
#  'contact',
#  'family',
#  'japan',
#  'created',
#  'person',
#  'finder',
#  'speech',
#  'conf',
#  'sxswh',
#  'sxsh',
#  'medical',
#  'blog',
#  'mhealth',
#  'provide',
#  'charger',
#  'changed',
#  'mind',
#  'next',
#  'wonder',
#  'flashmob',
#  'tcrn',
#  'ch',
#  'fcs45j',
#  'tip',
#  'api',
#  'suxsw',
#  'xmas',
#  'shiny',
#  'garyvee',
#  'christmas',
#  'nerd',
#  'yai',
#  'cont',
#  'yes',
#  'another',
#  'gem',
#  'presenting',
#  'local',
#  'gsd',
#  'industry',
#  'welivehere',
#  'gsdm',
#  'buzz',
#  'headline',
#  'hmm',
#  'could',
#  'seen',
#  'dataviz',
#  'translates',
#  'satanic',
#  'sayin',
#  'launched',
#  'checkins',
#  'month',
#  'ago',
#  'in',
#  'ok',
#  'out',
#  'bizzy',
#  'left',
#  'brain',
#  'x',
#  'bettersearch',
#  'engine',
#  'hp',
#  'park',
#  'content',
#  'incubator',
#  'construct',
#  'c',
#  'lewis',
#  'level',
#  'reasoning',
#  'continued',
#  'existence',
#  'evidence',
#  'bawling',
#  'pagemaker',
#  'saved',
#  'jwtatl',
#  'enchantment',
#  'spark',
#  'teamandroid',
#  'award',
#  'read',
#  'unboxing',
#  'thought',
#  'apac',
#  'region',
#  'dealing',
#  'earthquake',
#  'tsunami',
#  'trauma',
#  'school',
#  'marketing',
#  'expert',
#  'cnet',
#  'temporary',
#  'def',
#  'tent',
#  'powerhouse',
#  'gym',
#  '6th',
#  'congress',
#  'along',
#  '10',
#  '000',
#  'happy',
#  'hipster',
#  'support',
#  'trending',
#  'nerdy',
#  'headed',
#  'newbie',
#  'enjoy',
#  'funny',
#  'matter',
#  'minute',
#  'point',
#  'least',
#  'according',
#  'twitter',
#  'christian',
#  'devs',
#  'maybe',
#  'wk',
#  'together',
#  'cool',
#  'ux',
#  'uxdes',
#  'remember',
#  'ultimately',
#  'aware',
#  'audience',
#  'targeted',
#  'towards',
#  'unexpected',
#  'experience',
#  'taken',
#  'storm',
#  'part',
#  'haz',
#  'ifrom',
#  'gr8',
#  'stack',
#  'waiting',
#  'mine',
#  'hassle',
#  'handled',
#  'perfectly',
#  'elusive',
#  'eurorscg',
#  'notatsxsw',
#  'download',
#  'nearby',
#  'pep',
#  'smallbiz',
#  'place',
#  'seo',
#  'samsung',
#  'sony',
#  'lead',
#  'atx',
#  'rg',
#  'south',
#  'korean',
#  'director',
#  '130',
#  'movie',
#  'entirely',
#  'beautiful',
#  'q1',
#  'prep',
#  'amazing',
#  'locally',
#  'focus',
#  'owns',
#  'billboard',
#  'pr20chat',
#  'share',
#  'gather',
#  'info',
#  'turn',
#  'business',
#  'card',
#  'broadcaster',
#  'btw',
#  'sold',
#  'model',
#  'vzw',
#  'sneaky',
#  'usual',
#  'hopping',
#  'beta',
#  'testing',
#  'moonbot',
#  'louisiana',
#  'ton',
#  'fastball',
#  'away',
#  'two',
#  'wifi',
#  '32g',
#  'black',
#  'cover',
#  'fo',
#  'attsxsw',
#  'bo',
#  'house',
#  'wondering',
#  'worth',
#  'trek',
#  'convention',
#  'center',
#  'everything',
#  'except',
#  '64gig',
#  'white',
#  'manage',
#  'known',
#  'jean',
#  'configuration',
#  'offered',
#  'promo',
#  'ninjafinder',
#  'suck',
#  'film',
#  'selling',
#  'shipment',
#  'ipads',
#  'yet',
#  'ecko',
#  'autodial',
#  'political',
#  'edreform',
#  'edtech',
#  'eduvc',
#  'fightthepaddle',
#  'poursite',
#  'learning',
#  'life',
#  'changing',
#  'impact',
#  'real',
#  'actual',
#  'bravo',
#  'lonelyplanet',
#  'guide',
#  'limited',
#  'lp',
#  'travel',
#  'mp3',
#  'downloads',
#  'heading',
#  'aclu',
#  'owt',
#  'prompt',
#  'memory',
#  'go',
#  'describe',
#  'childhood',
#  'walk',
#  'short',
#  'essential',
#  'tool',
#  'tradeshow',
#  'demo',
#  'theatre',
#  'presenter',
#  'following',
#  'realtime',
#  'four',
#  'listening',
#  'realizing',
#  'spoken',
#  'pick',
#  'willing',
#  'pay',
#  '50',
#  'grab',
#  'quick',
#  'hundred',
#  'ad',
#  'hoc',
#  'cost',
#  'solving',
#  'induced',
#  'toilet',
#  'crisis',
#  'monday',
#  'barry',
#  'diller',
#  'york',
#  'lunch',
#  'hotel',
#  'six',
#  'dirty',
#  'martini',
#  'seriously',
#  'constant',
#  'causing',
#  'lost',
#  'schedule',
#  'sync',
#  'wp7',
#  'ready',
#  'ur',
#  'blogging',
#  'conflagration',
#  'doofusness',
#  'attention',
#  'er',
#  'rumored',
#  'went',
#  'lousy',
#  'folk',
#  'learn',
#  'security',
#  'bsidesaustin',
#  'work',
#  'development',
#  'hire',
#  'io',
#  'developer',
#  'man',
#  'let',
#  'winning',
#  'picture',
#  '7',
#  'hit',
#  'spent',
#  'used',
#  'couple',
#  'city',
#  'block',
#  'behind',
#  '100',
#  'email',
#  'give',
#  'composed',
#  'reply',
#  'protip',
#  '10pm',
#  'ipad2s',
#  '1154',
#  'song',
#  'alone',
#  '150',
#  'million',
#  'currently',
#  'available',
#  '64gb',
#  '699',
#  'optional',
#  'leather',
#  '69',
#  'entertain',
#  'please',
#  'grateful',
#  'le',
#  'announce',
#  'detail',
#  'giveaway',
#  'wild',
#  'terrible',
#  'queue',
#  'course',
#  'snapping',
#  'keynote',
#  'slide',
#  '200m',
#  'credit',
#  'click',
#  'purchase',
#  '2nd',
#  'cocktail',
#  'texas',
#  'snowflake',
#  'cnngrill',
#  'southwest',
#  'sweet',
#  'ballroom',
#  '35',
#  'mile',
#  'per',
#  'driving',
#  'navigation',
#  'p',
#  'longer',
#  'wider',
#  '250',
#  'packing',
#  'extra',
#  'way',
#  'sunny',
#  'stow',
#  '4sqwill',
#  'attempt',
#  'cross',
#  'facebook',
#  'blocked',
#  'connection',
#  'lbswars',
#  '5',
#  'growing',
#  'step',
#  'bulletproof',
#  'strategy',
#  'rhjr',
#  'ux5',
#  'wandering',
#  'street',
#  'girl',
#  'stopped',
#  'ceviche',
#  'mojitos',
#  'juice',
#  'track',
#  'stage',
#  'use',
#  'frostwire',
#  'wi',
#  'fi',
#  'busy',
#  'week',
#  'ahead',
#  'amazon',
#  'believe',
#  'aussie',
#  '70',
#  'buyer',
#  'spreadsheet',
#  '270',
#  'plan',
#  'sixth',
#  'told',
#  'car',
#  'zimride',
#  'etc',
#  'ride',
#  'shareable',
#  'tablet',
#  'every',
#  'single',
#  'receiving',
#  'message',
#  'telling',
#  'sexy',
#  'response',
#  'fellow',
#  'picked',
#  'mophie',
#  'battery',
#  'lugging',
#  'huge',
#  'thats',
#  'took',
#  'piss',
#  'trade',
#  'pissing',
#  'kiiiiiilling',
#  'rumor',
#  'monger',
#  'preview',
#  'socbiz',
#  'fb',
#  'build',
#  '24',
#  'biggest',
#  'history',
#  'survey',
#  'starbucks',
#  'gift',
#  'research',
#  'gratification',
#  'retail',
#  'release',
#  '5pm',
#  'groupme',
#  'sound',
#  'incredible',
#  'reveal',
#  'closure',
#  'made',
#  'question',
#  'inside',
#  'fire',
#  'paraormal',
#  'activity',
#  'sanctuary',
#  'sketching',
#  'ar',
#  'interactivity',
#  'magic',
#  'lense',
#  'eduar',
#  'iie',
#  '85',
#  'si',
#  'swimsuit',
#  'issue',
#  'garage',
#  'add',
#  'instagram',
#  'socialsearch',
#  'aftrnoon',
#  'frozen',
#  'lake',
#  'photographing',
#  ...]

# %%
w1 = "great"
model.wv.most_similar(positive=w1)
# Out:
# [('place', 0.9998182058334351),
#  ('power', 0.9998030662536621),
#  ('gsdm', 0.9997943043708801),
#  ('mean', 0.9997237920761108),
#  ('seo', 0.9997225403785706),
#  ('group', 0.9997023344039917),
#  ('next', 0.9996985197067261),
#  ('card', 0.9996788501739502),
#  ('tim', 0.9996782541275024),
#  ('talk', 0.9996564388275146)]
